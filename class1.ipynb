# %% [markdown]
# Printing hello world - traditionally by Print command

# %%
print("Hello World")
# Out:
# Hello World

# %%
# variables, data types: string, integar, float, bool

name = "Sami Bhojani" #string
age = 30 #integar
height = 5.4 # float
print(f"student name: {name} and the age of {name} is: {age} and height of {name} is: {height}" )
if height > 4:
    boolean = True
else: booolean = False

print(boolean)

if boolean: print("Valid height")
else: print("Invalid")
# Out:
# student name: Sami Bhojani and the age of Sami Bhojani is: 30 and height of Sami Bhojani is: 5.4
# True
# Valid height

# %%
#variable over riding

subject = "Math"
print(subject)

subject = "programming"
print(subject)
# Out:
# Math
# programming

# %%
# line gap
print("my name is:\n", name)
# Out:
# my name is:
#  Sami Bhojani
