# %% [markdown]
# 1. Write a program that accepts a list from user and print the alternate element of list.

# %%
print("Weekly Tasks")

total_tasks = int(input("Enter total number of tasks: "))

tasks_list = []

# Taking student names as input
while len(tasks_list) < total_tasks:
    task_name = input("Task name: ")
    tasks_list.append(task_name)

print("\nAll weekly tasks:", tasks_list)

print("(alternate print):")
todays_tasks = []

# Printing alternate task
todays_tasks.append(tasks_list[0:len(tasks_list):2])


print("Today's Tasks List: ", todays_tasks)
# Out:
# Weekly Tasks
#
# All weekly tasks: ['get clients', 'send onboarding mails', 'send followup mails', 'send invoices', 'deliver work']
# (alternate print):
# Today's Tasks List:  [['get clients', 'send followup mails', 'deliver work']]

# %% [markdown]
# 2. Write a program that accepts a list from user. Your program should reverse the content of list and
# display it. Do not use reverse() method.

# %%
max_std = 5
std_list = []

while len(std_list) < max_std:
    std = input("Enter student name: ")
    std_list.append(std)
print(f"FIFO order student queue: {std_list}")

# reverse order

reverse_list = []
while len(std_list) > 0:
    reverse_list.append(std_list.pop())
print(f"LIFO order student queue: {reverse_list}")
# Out:
# FIFO order student queue: ['sami', 'shumas', 'faizan', 'bilal', 'ahmed']
# LIFO order student queue: ['ahmed', 'bilal', 'faizan', 'shumas', 'sami']

# %% [markdown]
# 3. Find and display the largest number of a list without using built-in function max(). Your program
# should ask the user to input values in list from keyboard.

# %%
print("Finding max height - tallest student")

std_total = int(input("Total no. of Students: "))
std_heights = []


for std in range(0, std_total):
    std_height = int(input(f"Student{std} Height: "))
    std_heights.append(std_height)

# getting max value from the list
print(f"Heights: {std_heights}")
def calculate_max_height(tallest_std = std_heights[0]):
    for height in std_heights:
        if height > tallest_std:
            tallest_std = height
    return tallest_std

print(f"The height of tallest student: {calculate_max_height()} ft.")
# Out:
# Finding max height - tallest student
# Heights: [9, 2, 6, 5, 10]
# The height of tallest student: 10 ft.

# %% [markdown]
# 4. Write a program that rotates the element of a list so that the element at the first index moves to the
# second index, the element in the second index moves to the third index, etc., and the element in the last
# index moves to the first index.

# %%
total_elements = int(input("Enter no. of elements of the list: "))

numbers = []

while len(numbers) < total_elements:
    num = int(input("Enter Numbers: "))
    numbers.append(num)

print(f"Original List: {numbers}")

last_element = numbers.pop()
numbers.insert(0, last_element)

print(f"Rotated list: {numbers}")
# Out:
# Original List: [1, 2, 3, 4, 5]
# Rotated list: [5, 1, 2, 3, 4]

# %% [markdown]
# Write a program with a function that accepts a string from keyboard and create a new string after
# converting character of each word capitalized. For instance, if the sentence is "stop and smell the roses."
# the output should be "Stop And Smell The Roses"

# %%
def capitalizing_sentence(sentence):
    print(f"User's input sentence: '{sentence}'")
    print(f"Capitalised: ", sentence.title())

capitalizing_sentence(sentence= input("Enter a Sentence: "))
# Out:
# User's input sentence: 'stop and smell the roses.'
# Capitalised:  Stop And Smell The Roses.

# %% [markdown]
# Write a program to add two matrices of size n x m.
